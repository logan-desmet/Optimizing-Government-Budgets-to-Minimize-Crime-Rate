# %%
import pandas as pd

# %%
acs15_21 = pd.read_csv("acs2015-21_noColNames.csv")
acs15 = pd.read_csv("acs2015_postPrep.csv")

# %%
acs15_21
# Out:
#      Year       GEO_ID                  NAME  S0201_001E  S0201_002E  \
# 0    2015    Geography  Geographic Area Name         NaN         NaN
# 1    2015  0400000US01               Alabama   4858979.0        98.2
# 2    2015  0400000US02                Alaska    738432.0        91.4
# 3    2015  0400000US04               Arizona   6828065.0        96.7
# 4    2015  0400000US05              Arkansas   2978204.0        97.8
# ..    ...          ...                   ...         ...         ...
# 307  2016  0400000US51              Virginia   8411808.0        96.3
# 308  2016  0400000US53            Washington   7288000.0        94.3
# 309  2016  0400000US54         West Virginia   1831102.0        98.3
# 310  2016  0400000US55             Wisconsin   5778709.0        97.6
# 311  2016  0400000US56               Wyoming    585501.0        97.4
#
#      S0201_003E  S0201_004E  S0201_005E  S0201_006E  S0201_007E  ...  \
# ...

# %%
colNames = list(acs15.loc[0])
colNames[0] = "Year"
colNames = colNames[:-2]

# %%
acs15_21.columns = colNames

# %%
acs15_21.to_csv("acs2015-21_wcolnames.csv")
