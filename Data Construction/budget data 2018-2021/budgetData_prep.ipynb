# %%
import pandas as pd

# %%
bdata = pd.read_csv("2019budgetData_prePrep.csv")

# %%
bdata.loc[0, "F2"]
# Out:
# 'Description'

# %%
prevCol = None

for col in bdata:
  indicator = bdata[col][2]
  if indicator=="CV":
    bdata = bdata.drop([col], axis=1)

bdata
# Out:
#                                F2                   F3             F8  \
# 0                     Description  United States Total        Alabama
# 1                             NaN        State & local  State & local
# 2                             NaN              amount1        amount1
# 3                             NaN                    1              1
# 4                     Description                   C1             C6
# ..                            ...                  ...            ...
# 149                   By purpose:                  NaN            NaN
# 150               Offsets to debt          755,470,917      2,941,192
# 151                    Bond funds          250,326,583      3,022,136
# 152                         Other        1,913,239,021     22,708,818
# 153  Revision date: June 26, 2023                  NaN            NaN
#
#                F13            F18            F23            F28  \
# ...

# %%
bdata = bdata.drop([1, 2, 3, 4])

# %%
bdata.columns = bdata.iloc[0]

# %%
bdata = bdata.drop([0])

# %%
bdata.to_csv("19budgetData_post1prep.csv")

# %%
bdata
# Out:
# 0                     Description United States Total     Alabama      Alaska  \
# 5                        Revenue1       4,073,109,422  53,516,481  13,912,638
# 6                General revenue1       3,464,410,792  44,823,455  12,152,668
# 7      Intergovernmental revenue1         762,034,820  12,403,701   3,929,975
# 8         From Federal Government         762,034,820  12,403,701   3,929,975
# 9          From State government1                   0           0           0
# ..                            ...                 ...         ...         ...
# 149                   By purpose:                 NaN         NaN         NaN
# 150               Offsets to debt         755,470,917   2,941,192   4,315,798
# 151                    Bond funds         250,326,583   3,022,136     398,628
# 152                         Other       1,913,239,021  22,708,818  80,000,675
# 153  Revision date: June 26, 2023                 NaN         NaN         NaN
#
# ...
